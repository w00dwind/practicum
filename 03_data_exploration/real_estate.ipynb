# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#План-работы-над-проектом:" data-toc-modified-id="План-работы-над-проектом:-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>План работы над проектом:</a></span></li></ul></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Таблица-с-пропусками" data-toc-modified-id="Таблица-с-пропусками-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Таблица с пропусками</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Пропуски-в-данных-остались.-Заменим-их-с-помощью-алгоритма-KNN" data-toc-modified-id="Пропуски-в-данных-остались.-Заменим-их-с-помощью-алгоритма-KNN-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Пропуски в данных остались. Заменим их с помощью алгоритма KNN</a></span></li><li><span><a href="#Выводы-по-предобработке-данных:" data-toc-modified-id="Выводы-по-предобработке-данных:-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Выводы по предобработке данных:</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Распределение-признаков:-площадь,-цена,-число-комнат,-высота-потолков" data-toc-modified-id="Распределение-признаков:-площадь,-цена,-число-комнат,-высота-потолков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Распределение признаков: площадь, цена, число комнат, высота потолков</a></span></li><li><span><a href="#Время-продажи-квартиры." data-toc-modified-id="Время-продажи-квартиры.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Время продажи квартиры.</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили." data-toc-modified-id="Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры?</a></span><ul class="toc-item"><li><span><a href="#Выводы-на-основе-корреляций:" data-toc-modified-id="Выводы-на-основе-корреляций:-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Выводы на основе корреляций:</a></span></li><li><span><a href="#Зависимость-стоимости-от-этажа" data-toc-modified-id="Зависимость-стоимости-от-этажа-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Зависимость стоимости от этажа</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Зависимость-цены-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Зависимость цены от даты размещения: дня недели, месяца и года.</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.4.3.1"><span class="toc-item-num">4.4.3.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений.</a></span><ul class="toc-item"><li><span><a href="#Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах." data-toc-modified-id="Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Посчитайте среднюю цену квадратного метра в этих населённых пунктах.</a></span></li><li><span><a href="#Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья." data-toc-modified-id="Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Выделите населённые пункты с самой высокой и низкой стоимостью жилья.</a></span></li></ul></li><li><span><a href="#Выделите-квартиры-в-Санкт-Петербурге" data-toc-modified-id="Выделите-квартиры-в-Санкт-Петербурге-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Выделите квартиры в Санкт-Петербурге</a></span><ul class="toc-item"><li><span><a href="#Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений" data-toc-modified-id="Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Создайте столбец с расстоянием до центра в километрах: округлите до целых значений</a></span></li><li><span><a href="#После-этого-посчитайте-среднюю-цену-для-каждого-километра." data-toc-modified-id="После-этого-посчитайте-среднюю-цену-для-каждого-километра.-4.6.2"><span class="toc-item-num">4.6.2&nbsp;&nbsp;</span>После этого посчитайте среднюю цену для каждого километра.</a></span><ul class="toc-item"><li><span><a href="#Определение-границы-центра" data-toc-modified-id="Определение-границы-центра-4.6.2.1"><span class="toc-item-num">4.6.2.1&nbsp;&nbsp;</span>Определение границы центра</a></span></li></ul></li></ul></li><li><span><a href="#Выделите-сегмент-квартир-в-центре." data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделите сегмент квартир в центре.</a></span><ul class="toc-item"><li><span><a href="#Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков." data-toc-modified-id="Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Изучите следующие параметры: площадь, цена, число комнат, высота потолков.</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.7.1.1"><span class="toc-item-num">4.7.1.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ### План работы над проектом:
# * Предобработка данных: работа с пропусками, удаление выбросов и аномалий,
# * Добавление признаков, на основе имеющихся данных, для более качественного последующего анализа.
#     * Цена м2
#     * День, месяц и год публикации объявления
#     * Категория этажа квартиры
#     * Соотношения жилой к общей и кухонной к общей площадей.
# * Исследовательский анализ
#     * Подробнее посмотрим на взаимосвязь отдельных признаков
#     * Сравним выборки с окраин и в центре.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import numpy as np
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 8]
import seaborn as sns
# from sklearn.impute import KNNImputer
import os
import warnings
warnings.filterwarnings('ignore')

# %%
# чтение файла с данными и сохранение в df
local_path = '../datasets/real_estate_data.csv'
cloud_path = '/datasets/real_estate_data.csv'

if os.path.exists(local_path):
    df = pd.read_csv(local_path, sep='\t')
elif os.path.exists(cloud_path):
    df = pd_read_csv(cloud_path, sep='\t')
else:
    print('Something wrong with path.')


df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
print('\n* '.join(df.columns.to_list()))
# Out:
# total_images
# * last_price
# * total_area
# * first_day_exposition
# * rooms
# * ceiling_height
# * floors_total
# * living_area
# * floor
# * is_apartment
# * studio
# * open_plan
# * kitchen_area
# * balcony
# * locality_name
# * airports_nearest
# * cityCenters_nearest
# * parks_around3000
# * parks_nearest
# * ponds_around3000
# * ponds_nearest
# * days_exposition

# %%
df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Таблица с пропусками

# %% [markdown]
# **Таблица с пропусками удобна, т.к. она отсортирует значения пропусков по их доле. Мы сможем возвращаться к ней каждый раз, когда обработаем столбец с пропусками.**
#
# **Первой строчкой всегда будет название колонки с максимальным кол-вом пропусков на текущий момент**

# %%
# https://stackoverflow.com/questions/26266362/how-to-count-the-nan-values-in-a-column-in-pandas-dataframe

def missing_values_table(df):
    mis_val = df.isna().sum()      # variable with sum of nan values in dataframe
    mis_val_percent = 100 * df.isna().sum() / len(df)    # percent of missing values
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)    # concatenate total sum of Nan and percent.
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'missing_count', 1 : 'perc_of_total'})    # rename columns
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    'perc_of_total', ascending=False).round(1)               # sort values by percent of missing values in column
    print ("Количество колонок в датасете: " + str(df.shape[1]) + " \n"      
        "Пропуски имеют " + str(mis_val_table_ren_columns.shape[0]) +
            " колонок")
    return mis_val_table_ren_columns

# %%
# nan values by column count and percent

missing_values = missing_values_table(df)
missing_values
# Out:
# Количество колонок в датасете: 22
# Пропуски имеют 14 колонок
#                      missing_count  perc_of_total
# is_apartment                 20924           88.3
# parks_nearest                15620           65.9
# ponds_nearest                14589           61.6
# balcony                      11519           48.6
# ceiling_height                9195           38.8
# airports_nearest              5542           23.4
# cityCenters_nearest           5519           23.3
# parks_around3000              5518           23.3
# ponds_around3000              5518           23.3
# days_exposition               3181           13.4
# kitchen_area                  2278            9.6
# living_area                   1903            8.0
# floors_total                    86            0.4
# locality_name                   49            0.2

# %% [markdown]
# **Видим довольно много пропущенных данных. Ясно, что удалять данные с большим колиеством пропусков нельзя, поэтому посмотрим поближе, какие есть значения в признаках, где много пропусков**

# %%
# Let's see which values we have in 'is_apartment' feature
df['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# **Апартаменты - довольно редкий вид недвижимости, на его долю приходится едва ли больше 10%. Поскольку в задании написано, что мы исследуем продажу квартир, а не узкого среза (например аппартаментов), заменим все пропущенные значения в этой колонке на False.**
#
# **Большое количество пропущенных значений в этой колонке, скорее всего связано с тем, что это не является обязательным полем для заполнения. Клиенты явно не указывают тип недвижимости в объявлении**

# %%
# fill nan values to 'False'
df['is_apartment'] = df['is_apartment'].fillna('False')

# Check
assert df['is_apartment'].isna().sum() == 0, 'Остались пустые значения !'

# %% [markdown]
# ---

# %% [markdown]
# **Теперь посмотрим на столбец `parks_nearest`, в котором 66% пропущенных значений. Есть предположение, что пропущенное значение может означать отсутствие парка поблизости. Для проверки этой гипотезы отфильтруем данные так, чтобы в колонке `parks_nearest` было пустое значение и посмотрим какие значения в этой выборке принимает`parks_around3000`**

# %%
df[df['parks_nearest'].isna()]['parks_around3000'].value_counts(dropna=False)
# Out:
# 0.0    10102
# NaN     5518
# Name: parks_around3000, dtype: int64

# %% [markdown]
# **Как минимум для 10 тысяч наблюдений гипотеза верна, но остается еще 5518 наблюдений, с пропущенными данными.**
#
# **Перевернём конструкцию и посмотрим, какие значения принимает `parks_nearest` в строках с пропущенными значениями `parks_around3000`**

# %%
df[df['parks_around3000'].isna()]['parks_nearest'].value_counts(dropna=False)
# Out:
# NaN    5518
# Name: parks_nearest, dtype: int64

# %% [markdown]
# **Очень подозрительно выглядит одинаковое число пропущенных значений в обеих колонках. Посмотрим на срез, где все значения признака `park_nearest` - пропущены, и посмотрим, есть ли пропущенные значения в других признаках этого среза**

# %%
df[df['parks_nearest'].isna()].isna().sum().loc[lambda x: x > 0]
# Out:
# ceiling_height          6410
# floors_total              52
# living_area             1326
# kitchen_area            1588
# balcony                 7402
# locality_name             34
# airports_nearest        5522
# cityCenters_nearest     5518
# parks_around3000        5518
# parks_nearest          15620
# ponds_around3000        5518
# ponds_nearest          11334
# days_exposition         2036
# dtype: int64

# %% [markdown]
# **Видим, что признаки `airports_nearest`, `cityCenters_nearest`, `parks_around3000`, `ponds_around3000` имеют одинаковое количество пропущенных значений. Сделаем срез и посмотрим, пересекаются ли эти строки ?**

# %%
df[df['airports_nearest'].isna() &
  df['cityCenters_nearest'].isna() & 
  df['parks_around3000'].isna() & 
  df['ponds_around3000'].isna()].isna().sum().loc[lambda x: x > 0]
# Out:
# ceiling_height         2575
# floors_total             10
# living_area             623
# kitchen_area            715
# balcony                2710
# locality_name             8
# airports_nearest       5518
# cityCenters_nearest    5518
# parks_around3000       5518
# parks_nearest          5518
# ponds_around3000       5518
# ponds_nearest          5518
# days_exposition         865
# dtype: int64

# %% [markdown]
# **Пересечения есть в 5518 случаях. Посчитаем долю строк с большим кол-вом пропусков**

# %%
print(f"Доля строк с пересекающимися пропущенными значениями: {5518 / df.shape[0]:.2%}")
# Out:
# Доля строк с пересекающимися пропущенными значениями: 23.28%

# %% [markdown]
# **Мы не можем позволить себе удалить ~23.3 процента данных, поэтому будем действовать точечно, заменя значения отдельно в каждой колонке**

# %% [markdown]
# **Скорее всего пропущенные значения `parks_nearest` - это отсутствие парка поблизости, заменяем эти значения на 0. Так же на 0 заменим пропущенные значения признака `parks_around3000`**

# %%
df['parks_nearest'] = df['parks_nearest'].fillna(0)
df['parks_around3000'] = df['parks_around3000'].fillna(0)

assert (df['parks_nearest'].isna().sum() +
        df['parks_around3000'].isna().sum() == 0), \
        'Пропуски в колонках остались! '

# %% [markdown]
# ---

# %% [markdown]
# **Переходим к следующему по объему пропущенных значений столбцу - `ponds_nearest`. Посмотрим на него в том же разрезе, что и на `parks_nearest`**

# %%
(df[df['ponds_nearest'].isna()]['ponds_around3000'].value_counts(dropna=False))
# Out:
# 0.0    9071
# NaN    5518
# Name: ponds_around3000, dtype: int64

# %%
(df[df['ponds_around3000'].isna()]['ponds_nearest'].value_counts(dropna=False))
# Out:
# NaN    5518
# Name: ponds_nearest, dtype: int64

# %% [markdown]
# **Мы видим полное сходство с ситуацией по признаку `parks_nearest`. Действуем соответственно: заменяем пропущенные значения в обеоих столбцах на 0**

# %%
df['ponds_nearest'] = df['ponds_nearest'].fillna(0)
df['ponds_around3000'] = df['ponds_around3000'].fillna(0)

assert (df['ponds_nearest'].isna().sum() +
        df['ponds_around3000'].isna().sum() == 0), \
        'Пропуски в колонках остались! '

# %% [markdown]
# ---

# %% [markdown]
# **Переходим к балконам.**

# %%
df['balcony'].value_counts(dropna=False)
# Out:
# NaN    11519
# 1.0     4195
# 0.0     3758
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64

# %% [markdown]
# **Если балкон не указан в объявлении, скорее всего балкона нет вовсе. Устраним это недоразумение**

# %%
df['balcony'] = df['balcony'].fillna(0)

assert df['balcony'].isna().sum() == 0, 'Пропуски остались !'

# %% [markdown]
# ---

# %% [markdown]
# **Ниже функция для отрисовки медианы на гистограме распределения**

# %%
# Function to plot distribution with median

def median_plot(df, column, bins=10, range=None):
    column_median = df[column].median()

    df[column].plot(kind='hist',
                    title=str(column + '_distribution'),
                    bins=bins,
                    range=range)
    plt.axvline(column_median, 
                        color='k', 
                        linestyle='--', 
                        linewidth=2)
    print(f"Медиана {column}: {column_median}")

# %% [markdown]
# **Обработаем значения признака `celling_height`. Сперва посмотрим на распределение признака**

# %%
median_plot(df, 'ceiling_height', bins=50)
# Out:
# Медиана ceiling_height: 2.65

# %%
# Посмотрим подробнее на значения в диапазоне 20-40 и 90-100
df['ceiling_height'].hist(bins=30, range=(20, 40))
df['ceiling_height'].hist(bins=30, range=(90, 100), figsize=(15,4));

# %% [markdown]
# **Пики в в диапазоне 23-28м - могут быть просто ошибкой, поделим значения этого диапазона на 10 и получим метры**

# %%
# Делим значения в диапазоне 23-28м на 10.
df['ceiling_height'] = df['ceiling_height'].apply(lambda x: x / 10 if 23 < x < 28 else x)

# %%
# Посмотрим сколько строк с потолками выше 5м
print(f'Кол-во квартир с потолками выше 5м. - {df.query("ceiling_height > 5").shape[0]}')
# Out:
# Кол-во квартир с потолками выше 5м. - 18

# %%
# Удаляем квартиры с высотой потолков более 5 м.
df.drop(df[df.ceiling_height > 5].index, inplace=True)

# %% [markdown]
# ---

# %%
# Посмотрим есть ли данные, где количество этажей больше, чем указанный этаж квартиры
df[df['floor'] > df['floors_total']]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
# delete data with flat flor bigger then total flor and fill Nan to median
df.drop(df[df['floor'] > df['floors_total']].index, inplace=True)

# if floors_total is missing, fill with floor value
df['floors_total'].where(~df['floors_total'].isna(), df['floor'], inplace=True)

# %% [markdown]
# ---

# %%
print(f'Количество без указания населенного пункта: {df.query("locality_name.isna()").shape[0]}')
# Out:
# Количество без указания населенного пункта: 49

# %% [markdown]
# **49 строк можно смело удалить**

# %%
# Удаляем пропуски в колонке "населенный пункт"
df.drop(df[df['locality_name'].isna()].index, inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ### Изменение типов данных

# %%
# Datetime col has 'object' type. To work with it later, we have to change it to 'datetime'
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'])
# Floors in building can only take integer values 
df['floors_total'] = df['floors_total'].astype('int')
# 'Is apartment' col take  only two arguments - True and False. Its boolean type
df['is_apartment'] = df['is_apartment'].astype('bool')
# Balcony col can only take integer values
df['balcony'] = df['balcony'].astype('int')
# Days exposition can't be float. 
# df['days_exposition'] = df['days_exposition'].astype('int')

# %%
missing_values_table(df)
# Out:
# Количество колонок в датасете: 22
# Пропуски имеют 6 колонок
#                      missing_count  perc_of_total
# ceiling_height                9160           38.8
# airports_nearest              5532           23.4
# cityCenters_nearest           5509           23.3
# days_exposition               3175           13.4
# kitchen_area                  2264            9.6
# living_area                   1896            8.0

# %% [markdown]
# ### Пропуски в данных остались. Заменим их с помощью алгоритма KNN

# %%
# check 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23632 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23632 non-null  int64
#  1   last_price            23632 non-null  float64
#  2   total_area            23632 non-null  float64
#  3   first_day_exposition  23632 non-null  datetime64[ns]
#  4   rooms                 23632 non-null  int64
#  5   ceiling_height        14472 non-null  float64
#  6   floors_total          23632 non-null  int64
#  7   living_area           21736 non-null  float64
#  8   floor                 23632 non-null  int64
#  9   is_apartment          23632 non-null  bool
#  10  studio                23632 non-null  bool
#  11  open_plan             23632 non-null  bool
#  12  kitchen_area          21368 non-null  float64
#  13  balcony               23632 non-null  int64
#  14  locality_name         23632 non-null  object
# ...

# %%
# Следующие шаги предполагается выполнить позже, но я перенёс их сюда, т.к. возможно это поможет KNN лучше заполнить пропуски

# price of sqare meter
df['sqmeter_price'] = df['last_price'] / df['total_area']
# day of week
df['day_of_week'] = df['first_day_exposition'].dt.weekday
# month number
df['month'] = df['first_day_exposition'].dt.month
# Year 
df['year'] = df['first_day_exposition'].dt.year

# %%
# columns pass to KNN
columns_to_include = df.select_dtypes(include=['int', 'float']).columns
# all columns of dataframe
all_columns = df.columns
# columns not in columns_to_include
columns_to_exclude = [c for c in all_columns if c not in columns_to_include]

imputer = KNNImputer()
df_transformed = imputer.fit_transform(df[columns_to_include])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 8
#       5 # columns not in columns_to_include
#       6 columns_to_exclude = [c for c in all_columns if c not in columns_to_include]
# ----> 8 imputer = KNNImputer()
#       9 df_transformed = imputer.fit_transform(df[columns_to_include])
#
# NameError: name 'KNNImputer' is not defined

# %%
# Make dataframe from numpy matrix
df_transformed = pd.DataFrame(df_transformed, columns=columns_to_include)

# add columns from base dataframe
df_transformed = df_transformed.join(df[columns_to_exclude])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Make dataframe from numpy matrix
# ----> 2 df_transformed = pd.DataFrame(df_transformed, columns=columns_to_include)
#       4 # add columns from base dataframe
#       5 df_transformed = df_transformed.join(df[columns_to_exclude])
#
# NameError: name 'df_transformed' is not defined

# %%
# df_transformed
columns_to_change_type = ['total_images', 
                       'last_price', 
                       'rooms', 
                       'floors_total', 
                       'floor', 
                       'balcony', 
                       'parks_around3000', 
                       'ponds_around3000',
                       'sqmeter_price',
                       'day_of_week',
                       'month',
                       'year',
                      ]

df_transformed[columns_to_change_type] = df_transformed[columns_to_change_type].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 16
#       1 # df_transformed
#       2 columns_to_change_type = ['total_images',
#       3                        'last_price',
#       4                        'rooms',
#    (...)
#      13                        'year',
#      14                       ]
# ---> 16 df_transformed[columns_to_change_type] = df_transformed[columns_to_change_type].astype(int)
#
# NameError: name 'df_transformed' is not defined

# %%
df = df_transformed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df = df_transformed
#
# NameError: name 'df_transformed' is not defined

# %%
del df_transformed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 del df_transformed
#
# NameError: name 'df_transformed' is not defined

# %%
# check 
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # check
# ----> 2 df.info()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Выводы по предобработке данных:

# %% [markdown]
# 1. Большой объем данных имеет пропуски.
# 2. Признак `is_apartment` с болльшой долей вероятности имел пропуски там, где недвижимость являлась квартирой. Все пропуски заменены на `False`
# 3. В признаках `parks_nearest`, `parks_around3000` и `ponds_nearest`, `ponds_around3000` найдена взаимосвязь: если сделать срез по `parks_nearest` с пустыми значениями, `parks_around3000` принимает только два значения - 0 и Nan, если сделать обратный срез, выбрав только строки с пустыми значениями `parks_around3000`, признак `parks_nearest` имеет только пустые значения. **Все подобные случаи приравниваем к отсутствию парков и водоёмов поблизости, заменяем пропущенные значения на 0**
#
#     3.1 `balcony` - так же замена на 0, т.к. если балкон не указан в объявлении явно, скорее всего он отсутствует.
# 4. Остальные пропуски заполнены с помощью алгоритма KNN

# %% [markdown]
# **Пропуски в данных в большинстве случаев связаны с необязательностью заполнения данных, как в случае с признаком "Аппартаменты" или "Балкон". Так же есть технические ошибки при сборе, как в parks_around или localy_name**

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
# price of sqare meter

# df['sqmeter_price'] = df['last_price'] / df['total_area']

# %%
# # day of week
# df['day_of_week'] = df['first_day_exposition'].dt.weekday
# # month number
# df['month'] = df['first_day_exposition'].dt.month
# # Year 
# df['year'] = df['first_day_exposition'].dt.year

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
# Function to make floor category

def floor_cat(row):
    if row['floor'] == 1:
        cat = 'первый'
    elif row['floor'] == row['floors_total']:
        cat = 'последний'
    else: 
        cat = 'другой'
    return cat

df['floor_category'] = df.apply(floor_cat, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 12
#       9         cat = 'другой'
#      10     return cat
# ---> 12 df['floor_category'] = df.apply(floor_cat, axis=1)
#
# NameError: name 'df' is not defined

# %%
# Living x Total ratio
df['living_ratio'] = df['living_area'] / df['total_area']

# Kitchen x Total ratio
df['kitchen_ratio'] = df['kitchen_area'] / df['total_area']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Living x Total ratio
# ----> 2 df['living_ratio'] = df['living_area'] / df['total_area']
#       4 # Kitchen x Total ratio
#       5 df['kitchen_ratio'] = df['kitchen_area'] / df['total_area']
#
# NameError: name 'df' is not defined

# %%
# Заменяем неявные дубликаты
df['locality_name'] = df['locality_name'].replace('посе', 'посё').replace('поселок городского типа', 'ПГТ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Заменяем неявные дубликаты
# ----> 2 df['locality_name'] = df['locality_name'].replace('посе', 'посё').replace('поселок городского типа', 'ПГТ')
#
# NameError: name 'df' is not defined

# %%
# Находим квартиры, где сумма площадей кухни и гостиной больше 90% и удаляем их
area_anomaly = df[~(df['living_area'] + df['kitchen_area']  < df['total_area']*0.9)]
df.drop(area_anomaly.index, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Находим квартиры, где сумма площадей кухни и гостиной больше 90% и удаляем их
# ----> 2 area_anomaly = df[~(df['living_area'] + df['kitchen_area']  < df['total_area']*0.9)]
#       3 df.drop(area_anomaly.index, inplace=True)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Распределение признаков: площадь, цена, число комнат, высота потолков

# %%
# Total area distribution
median_plot(df, 'total_area', bins=100, range=(0,400))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Total area distribution
# ----> 2 median_plot(df, 'total_area', bins=100, range=(0,400))
#
# NameError: name 'df' is not defined

# %%
# check bias 
df.query("total_area > 300")['sqmeter_price'].hist( xrot=90);

# %% [markdown]
# **Видим, что есть объекты с большой площадью, где цена квадратного похожа на выброс, проверим это, сделав срез**

# %%
df.query("sqmeter_price > 750_000")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.query("sqmeter_price > 750_000")
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Странными выглядят только две квартиры с общей площадью 33 метра**

# %%
df.query("total_area == 33 and sqmeter_price > 750_000")['cityCenters_nearest']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.query("total_area == 33 and sqmeter_price > 750_000")['cityCenters_nearest']
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Квартиры находятся в самом центре, выброса нет, данные оставляем**

# %% [markdown]
# ___

# %%
# Price distribution
median_plot(df, 'last_price', range=(0,30_000_000), bins=50)
df['last_price'].describe()
# Out:
# Медиана last_price: 4650000.0
# count    2.274500e+04
# mean     6.495694e+06
# std      1.076794e+07
# min      1.219000e+04
# 25%      3.450000e+06
# 50%      4.650000e+06
# 75%      6.755060e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# **Большинство цен находятся в диапазоне до 10 млн. Медианная цена 4.65млн.**

# %% [markdown]
# ___

# %%
# rooms number
median_plot(df, 'rooms', bins=30,range=(0,15))
# Out:
# Медиана rooms: 2.0

# %%
median_plot(df, 'ceiling_height', range=(0,10), bins=20)

df['ceiling_height'].describe()
# Out:
# Медиана ceiling_height: 2.65
# count    22745.000000
# mean         2.716624
# std          0.238919
# min          1.000000
# 25%          2.550000
# 50%          2.650000
# 75%          2.790000
# max          4.900000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ### Время продажи квартиры.

# %%
# exposition time distribution
median_plot(df, 'days_exposition', range=(0,1400), bins=50)
plt.axvline(df['days_exposition'].mean(), color='orange', alpha=0.7)
plt.legend(['median', 'mean'])
print(f"Среднее время продажи: {df['days_exposition'].mean():.2f}")
df['days_exposition'].describe()
# Out:
# Медиана days_exposition: 110.0
# Среднее время продажи: 183.26
# count    22745.000000
# mean       183.259301
# std        209.399908
# min          1.000000
# 25%         45.000000
# 50%        110.000000
# 75%        239.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# #### Выводы
# 1. Среднее время продажи - 185 дней
# 2. Половина квартир продаётся за 102 дней или быстрее.
# 3. Если квартира продаётся дольше **239** дней(менее 25% выборки), это сильно больше обычного, возможно стоит предложить клиенту снизить цену, или сделать более привлекательные фотографии объекта.

# %% [markdown]
# ___

# %% [markdown]
# ### Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %% [markdown]
# **Мы уже избавились от квартир с неправдоподобно высокими потолками, а так же от квартир, где признак `floors_total` меньше признака `floors`**
#
# **Продолжим поиски. Отсортируем признаки по убыванию стандартного отклонения. В таких признаках вероятнее всего есть выбросы**

# %%
df.describe().T.sort_values('std', ascending=False)[['std', 'max']].round(2)
# Out:
#                              std           max
# last_price           10767938.37  7.630000e+08
# sqmeter_price           48378.13  1.907500e+06
# airports_nearest        11588.70  8.486900e+04
# cityCenters_nearest      9308.37  6.596800e+04
# parks_nearest             306.40  3.190000e+03
# ponds_nearest             305.40  1.344000e+03
# days_exposition           209.40  1.580000e+03
# total_area                 35.37  9.000000e+02
# living_area                21.53  4.097000e+02
# floors_total                6.55  6.000000e+01
# total_images                5.68  5.000000e+01
# kitchen_area                5.50  1.120000e+02
# floor                       4.85  3.300000e+01
# month                       3.49  1.200000e+01
# day_of_week                 1.79  6.000000e+00
# rooms                       1.07  1.900000e+01
# year                        1.04  2.019000e+03
# balcony                     0.96  5.000000e+00
# ponds_around3000            0.88  3.000000e+00
# ...

# %% [markdown]
# **созданные нами признаки `kitchen_ratio` и `living_ratio` по определению не могут быть больше единицы, а из таблицы выше, мы видим, что такие признаки есть. Посмотрим сколько таких данных**

# %%
perc_of_wrong_ratio = df.query("kitchen_ratio > 1 or living_ratio > 1")
print(f"Процент данных с ошибочным ratio {perc_of_wrong_ratio.shape[0] / df.shape[0]:.2%}")
# Out:
# Процент данных с ошибочным ratio 0.00%

# %% [markdown]
# **Отфильтруем значения за пределами усов (1.5 межквартильного размаха)**

# %%
def filter_quantile(data, column, plot=False):
    # computing Q1, Q3, IQR
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    # Filtering Values between Q1-1.5IQR and Q3+1.5IQR
    low_threshold = Q1 - 1.5 * IQR
    high_threshold = Q3 + 1.5 * IQR
    filtered_data = data[(data[column] >= low_threshold) & 
  (data[column] <= high_threshold)]

    # Boxplot
    if plot: 
        plt.figure()
        filtered_data[column].plot(kind='box')
        print(f"Процент данных с выбросами в {column}: {1 - filtered_data.shape[0] / data.shape[0]:.2%}")
        print(f"Нижний порог: {low_threshold:.2f}")
        print(f"Верхний порог: {high_threshold:.2f}")
    else:
        return filtered_data

# %%
filter_quantile(df, 'sqmeter_price', plot=True)
# Out:
# Процент данных с выбросами в sqmeter_price: 4.49%
# Нижний порог: 20441.00
# Верхний порог: 169553.00

# %% [markdown]
# **Стоимость м2 в центре города существенно выше стоимости м2 на окраине, посмотрим на распределение удаленности от центра отфильтрованных данных**

# %%
filtered_sqmeter = filter_quantile(df, 'sqmeter_price')
filtered_sqmeter['cityCenters_nearest'].hist(bins=30);

# %%
df.query("@df.index not in @filtered_sqmeter.index")['cityCenters_nearest'].hist(bins=30);

# %% [markdown]
# **После сравнения двух графиков удаленности от центра двух выборок - с высокой стоимостью м2 и нормальной, можем сделать вывод, что высокая стоимость м2 не связана с близостью к центру. Данные удаляем**

# %%
df = filtered_sqmeter.copy(deep=True)

# %%
filter_quantile(df, 'last_price', plot=True)
# Out:
# Процент данных с выбросами в last_price: 6.97%
# Нижний порог: -1057500.00
# Верхний порог: 10962500.00

# %% [markdown]
# **Оставим данные, 6.7% - многовоато, чтобы просто удалить их.**

# %%
filter_quantile(df, 'rooms', plot=True)
# Out:
# Процент данных с выбросами в rooms: 0.32%
# Нижний порог: -2.00
# Верхний порог: 6.00

# %% [markdown]
# **Квартиры с 6 комнатами и более удаляем**

# %%
df = df.query("index in (@filter_quantile(@df, 'rooms')).index")

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры?

# %% [markdown]
# **Для начала построим график корреляции, чтобы посмотреть на линейную взаимосвязь признаков**

# %%
columns_to_heatmap = df.select_dtypes(exclude=['bool', 'object', 'datetime64']).columns

plt.figure(figsize=(20,9));
sns.heatmap(df[columns_to_heatmap].corr(), cmap="YlGnBu", annot = True);

# %% [markdown]
# #### Выводы на основе корреляций:

# %% [markdown]
# 1. Большинство значений корреляции находятся в диапазоне от -0.5 до 0.5, что говорит о низкой линейной зависимости признаков.
# 2. Высокую корреляцию имеют лишь очевидные признаки. Например общая площадь зависит от цены, кол-ва комнат, жилой площади.
# 3. Так же обратная корреляция заметна у стоимости м2 и удаленности от центра. **Это значит, что стоимость  м2 в центре выше**

# %% [markdown]
# **График кол-ва дней размещения, в зависимости от года**

# %%
(df
    .pivot_table(index='year', values='days_exposition', aggfunc='count')
    .plot(style='o-',
          title='Количество объявлений по годам',
          linewidth=2,
         figsize=(16,5),
         legend=True),
);

# %%
(df
    .pivot_table(index='year', values='days_exposition', aggfunc='mean')
    .plot(style='o-',
          title='Среднее время размещения объявления',
          linewidth=2,
         figsize=(16,5),
         legend=True),
);

# %% [markdown]
# **Из графиков выше видно, что пик по количеству объявлений зафиксирован в 2017 году, однако сильно падает в 2019. Проверим, возможно у нас данные за неполный 2019 год**

# %%
df.groupby('year')['month'].nunique().plot(figsize=(16,5), style='o-', 
                                           title='Сколько всего месяцев внутри каждого года');

# %% [markdown]
# **Вывод - наиболее корректно считать данные в период с 2015 по 2018 годы, т.к. они содержат данные за все месяцы.**

# %% [markdown]
# #### Зависимость стоимости от этажа

# %%
last_price_pivot = df.pivot_table(index='floor_category', values='last_price').reset_index()
last_price_pivot.columns = ['floor_category', 'last_price']

plt.figure(figsize=(15,6))
sns.barplot(data = last_price_pivot.sort_values(by='last_price'), 
            x='floor_category', y='last_price')
plt.title('Полная стоимость квартиры в зависимости от этажа');

# %%
price_by_floor = (df
     .pivot_table(index='floor_category', values='sqmeter_price', aggfunc='median')
     .sort_values(by='sqmeter_price')).round(2).reset_index()

price_by_floor.columns = ['category','sqmeter_price']

plt.figure(figsize=(15,6))
sns.barplot(data=price_by_floor, x='category', y='sqmeter_price');

# %% [markdown]
# 1. Дешевле всего квартиры, расположенные на первых этажах.
# 2. Квартиры на последних этажах в среднем дороже.
# 3. Квартиры, между первым и последними этажами, в среднем - самые дорогие.
# Все выводы верны как для квадратного метра, так и для полной стоимости.

# %% [markdown]
# #### Зависимость цены от даты размещения: дня недели, месяца и года.

# %%
def relation_plot(data, index, values, aggfunc='mean'):
    return (data.pivot_table(index=index, 
                            values=values,
                            aggfunc=aggfunc)
                .sort_values(by=index)
                .plot(figsize=(15,5), 
                      linewidth=2,
                     grid=True)
           )

# %% [markdown]
# **Поскольку ранее мы выяснили, что имеем не полные данные за 2014 и 2019 год, дальнейшую аналитику будем проводить в диапазоне 2015-2018**

# %%
data_to_relation = df.query("2015 <= year <= 2018")

relation_plot(data_to_relation, 'year', 'sqmeter_price');

relation_plot(data_to_relation, 'month', 'sqmeter_price');

relation_plot(data_to_relation, 'day_of_week', 'sqmeter_price');

# %% [markdown]
# ##### Выводы
# 1. Самая высокая цена квадратного метра зарегистрирована в 2018, самая низкая в 2016, с 2016 по 2018 устойчивый тренд на рост.
#
# 2. Март и июнь - самые выгодные месяцы для покупки квартиры. Август и сентябрь - хорошее время для продажи квартиры.
#
# 3. Дороже всего выставляют квартиры во вторник, дешевле всего в пятницу.

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений.

# %%
top_locality_index = df['locality_name'].value_counts()[:10].index

# %%
top_locality = df.query("locality_name in @top_locality_index")

# %% [markdown]
# #### Посчитайте среднюю цену квадратного метра в этих населённых пунктах.

# %%
top_locality_pivot = (top_locality.pivot_table(index='locality_name', 
                         values='sqmeter_price')
                      .round(2)
                      .sort_values('sqmeter_price', ascending=False).reset_index()
)
top_locality_pivot.columns = ['locality_name', 'mean_m2_price']
top_locality_pivot
# Out:
#        locality_name  mean_m2_price
# 0    деревня Кудрово       94910.86
# 1  посёлок Парголово       94346.46
# 2    Санкт-Петербург       93838.76
# 3            Колпино       93631.55
# 4         Всеволожск       93364.90
# 5            Гатчина       92756.24
# 6             Выборг       92663.16
# 7             Пушкин       92477.43
# 8     посёлок Мурино       92306.47
# 9     посёлок Шушары       90731.24

# %% [markdown]
# #### Выделите населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
plt.figure(figsize=(16,6))
sns.barplot(data=top_locality_pivot.iloc[[0,1,8,9]], x='locality_name', y='mean_m2_price');

# %% [markdown]
# ---

# %% [markdown]
# ### Выделите квартиры в Санкт-Петербурге

# %%
spb_flats = df.query("locality_name == @df.locality_name.mode()[0]")

# %% [markdown]
# #### Создайте столбец с расстоянием до центра в километрах: округлите до целых значений

# %%
spb_flats.loc[:,'cityCenter_km'] = ((spb_flats['cityCenters_nearest'] / 1000)
                                .values.round(1)
)

# %% [markdown]
# #### После этого посчитайте среднюю цену для каждого километра.

# %%
# округлим 

spb_flats['cityCenter_km_int'] = spb_flats['cityCenter_km'].astype('int')

# %%
# нарисуем 

(
    spb_flats
        .query('cityCenter_km_int < 25')
        .groupby('cityCenter_km_int')['sqmeter_price']
        .mean()
        .plot(figsize=(15,5),grid=True,linewidth=2)
);

# %% [markdown]
# #####   Определение границы центра
# Все выглядит логично, по мере удаления от центра, цена м2 снижается, однако есть два пика: в районе 20км и 27км от центра.
# На основе графика можно выдвинуть гипотезу: В центре больше старого жилого фонда, по мере удаления от центра больше новостроек. В одном и том же районе (на равном удалении от центра) м2 в новостройке дороже м2 в старом жилом фонде. Поскольку в центре мало нового жилья, главной состовляющей цены м2 там является близость к центру, соответственно пики на 20 и 27 км объясняются наличием там новых жилих комплексов.
# Провал стоимости м2 на 29 км может говорить о неблагополучном районе, с неразвитой инфраструктурой и плохой транспортной доступностью.
#
# **Будем считать центром все, что в радиусе 10 км от центра**

# %% [markdown]
# ### Выделите сегмент квартир в центре.

# %%
spb_flats_center = spb_flats.query("cityCenter_km < 10")
spb_flats_suburban  = df.query("index not in @spb_flats_center")

# %% [markdown]
# #### Изучите следующие параметры: площадь, цена, число комнат, высота потолков.

# %%
def relation_plot_scatter(data, index, values, aggfunc='median', color='dodgerblue'):
     (data.pivot_table(index=index, 
                            values=values,
                            aggfunc=aggfunc)
                .reset_index()
                .plot(kind='scatter',
                      x=index,
                      y=values,
                    figsize=(10,5), 
                     grid=True,
                     color=color)
           )

# %%
# center flats price vs suburban flats price 
relation_plot_scatter(spb_flats_center, 'total_area', 'last_price');
plt.title('center');
relation_plot_scatter(spb_flats_suburban,'total_area', 'last_price', color='orange');
plt.title('suburban');

# %%
# Center flats m2 price vs suburban flats m2 price

relation_plot_scatter(spb_flats_center, 'total_area', 'sqmeter_price');
plt.title('center total_area x m2 price');
relation_plot_scatter(spb_flats_suburban, 'total_area', 'sqmeter_price', color='orange');
plt.title('suburban total_area x m2 price ');

# %%
def custom_hist(data, column, title='hist', bins=30, figsize=(7,5), color='dodgerblue', alpha=1):
    data[column].plot(kind='hist',
                     title=title,
                     bins=bins,
                     figsize=figsize,
                     color=color,
                     alpha=alpha)

# %%
custom_hist(spb_flats_center, 'total_area', 'center flats total area')
plt.show()
custom_hist(spb_flats_suburban, 'total_area', 'suburban_flats_total_area', color='orange')

# %%
custom_hist(spb_flats_center, 'rooms', 'center flats rooms distribution')
plt.show()
custom_hist(spb_flats_suburban, 'rooms', 'suburban flats rooms distribution', color='orange')

# %%
print(f"Средняя высота потолков в центре: {spb_flats_center['ceiling_height'].mean()}")
print(f"Средняя высота потолков на окраинах: {spb_flats_suburban['ceiling_height'].mean()}")

custom_hist(spb_flats_center, 'ceiling_height', 'center flats ceiling height distribution')
plt.show()
custom_hist(spb_flats_suburban, 'ceiling_height', 'suburban flats ceiling height distribution', color='orange')
# Out:
# Средняя высота потолков в центре: 2.931339608979001
# Средняя высота потолков на окраинах: 2.7005221206243655

# %%
plt.figure(figsize=(20,9));
sns.heatmap(spb_flats_center.corr(), cmap="YlGnBu", annot = True);
plt.title('suburban flats corr heatmap');

# %%
plt.figure(figsize=(20,9));
sns.heatmap(spb_flats_suburban.corr(), cmap="YlOrBr", annot = True);
plt.title('center flats corr heatmap');

# %% [markdown]
# ##### Выводы
# 1. Цена объекта линейно зависит от площади
# 2. Цена квадратного метра в центре выше в среднем на 16%
# 3. И в центре, и на периферии - большинство квартир имеют площадь до 100 м2. Однако в диапазоне 100-200м2 больше квартир в центре.
# 4. На окраинах более популярны однокомнатные и двухкомнатные квартиры. В центре - большинство квартир двухкомнатные и трехкомнатные, так же в центре больше квартир с 4 и более комнатами.
# 5. Средняя высота потолков в центре - 2.85м, на окраине - 2.68, однако на графике видно, что в центре больше квартир с высокими потолками.
# 6. На стоимость квартир в центре и на окраинах влияют похожие признаки, прежде всего размер квартиры. Однако на окраине стоимость м2 падает, по мере удаления от центра (обратная корреляция). Скорее всего это связано с благополучностью конкретного района и его транспортной доступностью.

# %% [markdown]
# ## Общий вывод
#
# 1. В данных очень большой объем пропусков, это может существенно повлиять на выводы из данных, рекомендуется улучшить сбор и обработку данных, возможно добавить обязательные поля для ввода при заполнении объявления.
# 2. Часть пропусков обработаны вручную, например балконы или апартаменты. Остальные признаки заменены с помощью алгоритма KNN.
# 3. При анализе признаков, влияющих на стоимость м2 сюрпризов не обнаружено. Похожие факторы влияют на стоимость квадратного метра в центре и на периферии, однако в отличие от центра, на окраинах дистанция от центра не играет большой роли в формировании стоимости. Так же этажность имеет больший вклад в цену м2 в центре. Потолки, кол-во комнат и общая площадь - в среднем больше у квартир в центре Санкт-Петербурга.
# 4. При анализе объявлений с полной базой, выявленно, что кол-во объявлений в 2018 ниже, чем в 2017. Надо разобраться с чем это связано - с более точной модерацией при публикации, или с меньшим интересом пользователей к площадке.
# 5. Средний срок размещения падает с каждым годом, это отличная новсть, значит сервис помогает продавать быстрее.
# 6. Для борьбы с фейковыми объявлениями лучше всего использовать комплексный подход:
#     1. Алгоритм, сверяющий загруженные фотографии на предмет уже существующих в базе
#     2. Сверка телефона человека, публикующего объявление, с базой мошенников.
#     3. Поиск объявлений с одинаковым описанием и последующая маркировка как подозрительных.
